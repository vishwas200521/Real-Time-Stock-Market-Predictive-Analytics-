# %%
import pandas as pd
df = pd.read_csv("../data/stock.csv")

# %%
df.head()
# Out:
#          Date      Close       High        Low       Open     Volume
# 0  2020-01-02  72.333878  72.394086  71.091184  71.344054  135480400
# 1  2020-01-03  71.630638  72.389257  71.406666  71.563205  146322800
# 2  2020-01-06  72.201408  72.239942  70.503546  70.754014  118387200
# 3  2020-01-07  71.861832  72.466315  71.642674  72.211033  108872000
# 4  2020-01-08  73.017815  73.318854  71.565599  71.565599  132079200

# %%
df.shape
# Out:
# (1258, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   str
#  1   Close   1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Open    1258 non-null   float64
#  5   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 59.1 KB

# %%
df.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    151.377786   152.899566   149.680871   151.223470  9.057103e+07
# std      41.851999    41.992363    41.629303    41.795805  5.324438e+07
# min      54.163708    55.160705    51.324804    55.059316  2.323470e+07
# 25%     126.279119   127.397077   124.278508   125.724360  5.546825e+07
# 50%     149.968613   151.709757   148.037172   149.788890  7.628335e+07
# 75%     175.902031   177.452409   174.337230   175.708215  1.077425e+08
# max     257.375549   258.448710   255.994390   256.550832  4.265100e+08

# %%
df.columns
# Out:
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str')

# %%
df.isnull().sum()
# Out:
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# %%
df=pd.read_csv("../data/stock.csv")
df.head()
# Out:
#          Date      Close       High        Low       Open     Volume
# 0  2020-01-02  72.333878  72.394086  71.091184  71.344054  135480400
# 1  2020-01-03  71.630638  72.389257  71.406666  71.563205  146322800
# 2  2020-01-06  72.201408  72.239942  70.503546  70.754014  118387200
# 3  2020-01-07  71.861832  72.466315  71.642674  72.211033  108872000
# 4  2020-01-08  73.017815  73.318854  71.565599  71.565599  132079200

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   str
#  1   Close   1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Open    1258 non-null   float64
#  5   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 59.1 KB

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   datetime64[us]
#  1   Close   1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Open    1258 non-null   float64
#  5   Volume  1258 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 59.1 KB

# %%
df.isnull().sum()
# Out:
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1258, 6)

# %%
df.to_csv("../data/clean_stock.csv",index=False)

# %%
df.describe()
# Out:
#                              Date        Close         High          Low  \
# count                        1258  1258.000000  1258.000000  1258.000000
# mean   2022-07-01 15:39:46.645469   151.377786   152.899566   149.680871
# min           2020-01-02 00:00:00    54.163708    55.160705    51.324804
# 25%           2021-04-02 00:00:00   126.279119   127.397077   124.278508
# 50%           2022-06-30 12:00:00   149.968613   151.709757   148.037172
# 75%           2023-10-01 06:00:00   175.902031   177.452409   174.337230
# max           2024-12-31 00:00:00   257.375549   258.448710   255.994390
# std                           NaN    41.851999    41.992363    41.629303
#
#               Open        Volume
# count  1258.000000  1.258000e+03
# mean    151.223470  9.057103e+07
# min      55.059316  2.323470e+07
# 25%     125.724360  5.546825e+07
# 50%     149.788890  7.628335e+07
# 75%     175.708215  1.077425e+08
# max     256.550832  4.265100e+08
# std      41.795805  5.324438e+07

# %%
import pandas as pd
df=pd.read_csv("../data/clean_stock.csv")
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.shape
# Out:
# (1258, 6)

# %%
df.describe()
# Out:
#                              Date        Close         High          Low  \
# count                        1258  1258.000000  1258.000000  1258.000000
# mean   2022-07-01 15:39:46.645469   151.377786   152.899566   149.680871
# min           2020-01-02 00:00:00    54.163708    55.160705    51.324804
# 25%           2021-04-02 00:00:00   126.279119   127.397077   124.278508
# 50%           2022-06-30 12:00:00   149.968613   151.709757   148.037172
# 75%           2023-10-01 06:00:00   175.902031   177.452409   174.337230
# max           2024-12-31 00:00:00   257.375549   258.448710   255.994390
# std                           NaN    41.851999    41.992363    41.629303
#
#               Open        Volume
# count  1258.000000  1.258000e+03
# mean    151.223470  9.057103e+07
# min      55.059316  2.323470e+07
# 25%     125.724360  5.546825e+07
# 50%     149.788890  7.628335e+07
# 75%     175.708215  1.077425e+08
# max     256.550832  4.265100e+08
# std      41.795805  5.324438e+07

# %%
df.dtypes
# Out:
# Date      datetime64[us]
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# dtype: object

# %%
print(df["Date"].min())
print(df["Date"].max())
# Out:
# 2020-01-02 00:00:00
# 2024-12-31 00:00:00

# %%
df["Close"].max()
# Out:
# np.float64(257.37554931640625)

# %%
df["Close"].min()
# Out:
# np.float64(54.1637077331543)

# %%
df["Volume"].mean()
# Out:
# np.float64(90571034.6581876)

# %%
df.loc[df["Close"].idxmax()]
# Out:
# Date      2024-12-26 00:00:00
# Close              257.375549
# High                258.44871
# Low                 255.99439
# Open               256.550832
# Volume               27237100
# Name: 1254, dtype: object

# %%
df.loc[df["Volume"].idxmax()]
# Out:
# Date      2020-02-28 00:00:00
# Close               65.990067
# High                67.209159
# Low                 61.888623
# Open                62.103476
# Volume              426510000
# Name: 39, dtype: object

# %%
df.loc[1,"Close"]
# Out:
# np.float64(71.6306381225586)

# %%
df.loc[df["Close"]>150]
# Out:
#            Date       Close        High         Low        Open    Volume
# 422  2021-09-03  150.629547  150.951699  149.448324  150.102384  57808700
# 423  2021-09-07  152.962708  153.519141  150.717416  151.283621  82278300
# 424  2021-09-08  151.420303  153.304386  150.317179  153.245816  74420200
# 425  2021-09-09  150.405045  152.396511  150.287889  151.791264  57305700
# 474  2021-11-17  150.057510  151.533737  147.613418  147.623189  88807000
# ...         ...         ...         ...         ...         ...       ...
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019  23234700
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832  27237100
# 1255 2024-12-27  253.967392  257.057664  251.453455  256.193162  42355300
# 1256 2024-12-30  250.598907  251.890657  249.158116  250.628716  35557500
# 1257 2024-12-31  248.830231  251.672075  247.846510  250.837411  39480700
#
# [628 rows x 6 columns]

# %%
df.loc[df["Volume"]>200000000,["Date","Close"]]
# Out:
#            Date       Close
# 18   2020-01-29   78.111435
# 35   2020-02-24   71.981689
# 36   2020-02-25   69.543541
# 38   2020-02-27   66.028671
# 39   2020-02-28   65.990067
# 40   2020-03-02   72.133812
# 41   2020-03-03   69.842850
# 42   2020-03-04   73.082481
# 44   2020-03-06   69.772865
# 45   2020-03-09   64.254379
# 46   2020-03-10   68.882072
# 47   2020-03-11   66.489769
# 48   2020-03-12   59.923592
# 49   2020-03-13   67.102936
# 50   2020-03-16   58.470348
# 51   2020-03-17   61.041298
# 52   2020-03-18   59.547009
# 53   2020-03-19   59.090752
# 54   2020-03-20   55.339344
# 55   2020-03-23   54.163708
# 56   2020-03-24   59.597687
# 57   2020-03-25   59.269382
# 58   2020-03-26   62.388336
# 59   2020-03-27   59.805309
# 65   2020-04-06   63.361187
# 66   2020-04-07   62.627319
# 73   2020-04-17   68.268898
# 83   2020-05-01   69.782509
# 91   2020-05-13   74.468826
# 111  2020-06-11   81.306946
# 112  2020-06-12   82.008911
# 117  2020-06-19   84.652168
# ...

# %%
df.loc[9,["Date","Volume"]]
# Out:
# Date      2020-01-15 00:00:00
# Volume              121923600
# Name: 9, dtype: object

# %%
df.loc[24,"Open"]
# Out:
# np.float64(77.68516086755363)

# %%
df.loc[99,["Date","Open","Close"]]
# Out:
# Date     2020-05-26 00:00:00
# Open                78.30541
# Close              76.666687
# Name: 99, dtype: object

# %%
df.loc[df["Close"]>150]
# Out:
#            Date       Close        High         Low        Open    Volume
# 422  2021-09-03  150.629547  150.951699  149.448324  150.102384  57808700
# 423  2021-09-07  152.962708  153.519141  150.717416  151.283621  82278300
# 424  2021-09-08  151.420303  153.304386  150.317179  153.245816  74420200
# 425  2021-09-09  150.405045  152.396511  150.287889  151.791264  57305700
# 474  2021-11-17  150.057510  151.533737  147.613418  147.623189  88807000
# ...         ...         ...         ...         ...         ...       ...
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019  23234700
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832  27237100
# 1255 2024-12-27  253.967392  257.057664  251.453455  256.193162  42355300
# 1256 2024-12-30  250.598907  251.890657  249.158116  250.628716  35557500
# 1257 2024-12-31  248.830231  251.672075  247.846510  250.837411  39480700
#
# [628 rows x 6 columns]

# %%
df.loc[df["Close"]>df["Open"]]
# Out:
#            Date       Close        High         Low        Open     Volume
# 0    2020-01-02   72.333878   72.394086   71.091184   71.344054  135480400
# 1    2020-01-03   71.630638   72.389257   71.406666   71.563205  146322800
# 2    2020-01-06   72.201408   72.239942   70.503546   70.754014  118387200
# 4    2020-01-08   73.017815   73.318854   71.565599   71.565599  132079200
# 5    2020-01-09   74.568779   74.761442   73.742727   73.993187  170108400
# ...         ...         ...         ...         ...         ...        ...
# 1250 2024-12-19  248.204208  250.400185  245.521352  245.928753   60882300
# 1251 2024-12-20  252.874390  253.381146  244.130253  246.465325  147495300
# 1252 2024-12-23  253.649445  254.027022  251.840991  253.152619   40858800
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019   23234700
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832   27237100
#
# [685 rows x 6 columns]

# %%
df.loc[df['Volume']>150000000,["Date","Close"]]
# Out:
#            Date       Close
# 5    2020-01-09   74.568779
# 8    2020-01-14   75.303329
# 16   2020-01-27   74.405037
# 17   2020-01-28   76.509903
# 18   2020-01-29   78.111435
# ...         ...         ...
# 1091 2024-05-03  181.558868
# 1117 2024-06-11  205.370987
# 1118 2024-06-12  211.240143
# 1124 2024-06-21  205.708069
# 1187 2024-09-20  226.502090
#
# [136 rows x 2 columns]

# %%
df.loc[df["High"]>200,["Date","High","Close"]]
# Out:
#            Date        High       Close
# 1117 2024-06-11  205.380911  205.370987
# 1118 2024-06-12  218.308899  211.240143
# 1119 2024-06-13  214.888539  212.400101
# 1120 2024-06-14  213.322107  210.665131
# 1121 2024-06-17  217.069637  214.809219
# ...         ...         ...         ...
# 1253 2024-12-24  256.570737  256.560822
# 1254 2024-12-26  258.448710  257.375549
# 1255 2024-12-27  257.057664  253.967392
# 1256 2024-12-30  251.890657  250.598907
# 1257 2024-12-31  251.672075  248.830231
#
# [141 rows x 3 columns]

# %%
df.sort_values(by="Close")
# Out:
#            Date       Close        High         Low        Open     Volume
# 55   2020-03-23   54.163708   55.160705   51.324804   55.059316  336752800
# 54   2020-03-20   55.339344   60.792649   55.040002   59.670120  401693200
# 62   2020-04-01   58.156521   60.041882   57.726823   59.505966  176218400
# 64   2020-04-03   58.277225   59.312845   57.688200   58.612776  129880000
# 50   2020-03-16   58.470348   62.542821   57.936845   58.407581  322423600
# ...         ...         ...         ...         ...         ...        ...
# 1251 2024-12-20  252.874390  253.381146  244.130253  246.465325  147495300
# 1252 2024-12-23  253.649445  254.027022  251.840991  253.152619   40858800
# 1255 2024-12-27  253.967392  257.057664  251.453455  256.193162   42355300
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019   23234700
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832   27237100
#
# [1258 rows x 6 columns]

# %%
df.sort_values(by="Close",ascending=False)
# Out:
#            Date       Close        High         Low        Open     Volume
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832   27237100
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019   23234700
# 1255 2024-12-27  253.967392  257.057664  251.453455  256.193162   42355300
# 1252 2024-12-23  253.649445  254.027022  251.840991  253.152619   40858800
# 1251 2024-12-20  252.874390  253.381146  244.130253  246.465325  147495300
# ...         ...         ...         ...         ...         ...        ...
# 50   2020-03-16   58.470348   62.542821   57.936845   58.407581  322423600
# 64   2020-04-03   58.277225   59.312845   57.688200   58.612776  129880000
# 62   2020-04-01   58.156521   60.041882   57.726823   59.505966  176218400
# 54   2020-03-20   55.339344   60.792649   55.040002   59.670120  401693200
# 55   2020-03-23   54.163708   55.160705   51.324804   55.059316  336752800
#
# [1258 rows x 6 columns]

# %%
df.sort_values(by="Close",ascending=False).head(5)
# Out:
#            Date       Close        High         Low        Open     Volume
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832   27237100
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019   23234700
# 1255 2024-12-27  253.967392  257.057664  251.453455  256.193162   42355300
# 1252 2024-12-23  253.649445  254.027022  251.840991  253.152619   40858800
# 1251 2024-12-20  252.874390  253.381146  244.130253  246.465325  147495300

# %%
df.sort_values(by="Volume",ascending=False).head(10)
# Out:
#           Date       Close        High         Low        Open     Volume
# 39  2020-02-28   65.990067   67.209159   61.888623   62.103476  426510000
# 48  2020-03-12   59.923592   65.178947   59.868070   61.784814  418474000
# 54  2020-03-20   55.339344   60.792649   55.040002   59.670120  401693200
# 146 2020-07-31  102.883888  103.033962   97.621565   99.616119  374336800
# 49  2020-03-13   67.102936   67.573676   61.063019   63.945381  370732000
# 162 2020-08-24  122.078453  124.918056  120.216105  124.833175  345937600
# 40  2020-03-02   72.133812   72.768705   67.042611   68.143411  341397200
# 161 2020-08-21  120.635628  121.118187  115.669360  115.681482  338054800
# 55  2020-03-23   54.163708   55.160705   51.324804   55.059316  336752800
# 171 2020-09-04  117.327988  119.985713  107.560355  116.464712  332607200

# %%
df.sort_values(by=["Close","Volume"], ascending=[False,False])
# Out:
#            Date       Close        High         Low        Open     Volume
# 1254 2024-12-26  257.375549  258.448710  255.994390  256.550832   27237100
# 1253 2024-12-24  256.560822  256.570737  253.669277  253.868019   23234700
# 1255 2024-12-27  253.967392  257.057664  251.453455  256.193162   42355300
# 1252 2024-12-23  253.649445  254.027022  251.840991  253.152619   40858800
# 1251 2024-12-20  252.874390  253.381146  244.130253  246.465325  147495300
# ...         ...         ...         ...         ...         ...        ...
# 50   2020-03-16   58.470348   62.542821   57.936845   58.407581  322423600
# 64   2020-04-03   58.277225   59.312845   57.688200   58.612776  129880000
# 62   2020-04-01   58.156521   60.041882   57.726823   59.505966  176218400
# 54   2020-03-20   55.339344   60.792649   55.040002   59.670120  401693200
# 55   2020-03-23   54.163708   55.160705   51.324804   55.059316  336752800
#
# [1258 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display plots inside Jupyter
# %matplotlib inline

# Plot style
plt.style.use("ggplot")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       5 # Display plots inside Jupyter
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'
